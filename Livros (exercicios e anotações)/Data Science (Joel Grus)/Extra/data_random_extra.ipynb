# %%
from collections import Counter
from random import randint,seed
from matplotlib import pyplot as plt

seed(10) # random.randint

random_numbers = Counter(randint(1,1000) for i in range(1000000))


print(random_numbers)

plt.bar(
    x=random_numbers.keys(),
    height=random_numbers.values(),
    width=6,
    edgecolor=(0,0,0,0)
)


plt.axis([-50, 1050, 0, max(random_numbers.values()) + 1000])

plt.show()
# Out:
# Counter({175: 1153, 305: 1100, 82: 1099, 372: 1093, 380: 1091, 458: 1080, 544: 1080, 109: 1078, 827: 1076, 564: 1076, 133: 1076, 651: 1074, 497: 1070, 528: 1068, 231: 1068, 248: 1067, 887: 1065, 28: 1065, 126: 1065, 341: 1063, 34: 1062, 610: 1062, 519: 1062, 330: 1062, 904: 1062, 237: 1061, 350: 1060, 682: 1060, 673: 1059, 712: 1057, 817: 1057, 641: 1057, 427: 1057, 699: 1057, 125: 1057, 419: 1055, 578: 1055, 960: 1055, 743: 1055, 648: 1054, 258: 1054, 354: 1053, 483: 1053, 146: 1053, 2: 1053, 468: 1052, 915: 1052, 302: 1052, 308: 1052, 462: 1051, 55: 1051, 62: 1051, 835: 1051, 90: 1051, 98: 1050, 742: 1050, 661: 1050, 3: 1049, 143: 1048, 959: 1048, 980: 1048, 598: 1048, 317: 1048, 285: 1047, 116: 1047, 444: 1047, 555: 1047, 363: 1047, 617: 1046, 992: 1046, 962: 1046, 713: 1045, 513: 1045, 560: 1045, 433: 1044, 571: 1044, 795: 1043, 270: 1043, 810: 1043, 546: 1043, 693: 1043, 821: 1042, 708: 1042, 583: 1042, 228: 1042, 525: 1042, 436: 1042, 36: 1041, 652: 1041, 776: 1041, 264: 1041, 
# ...

# %%
from collections import Counter
from random import randint,seed
from matplotlib import pyplot as plt

seed(10) # random.randint

random_numbers: list[tuple[int]] = [(randint(1,1000) for i in range(2)) for i in range(100000)]

result: Counter[list[int]] = []
for a,b in random_numbers: 
    result += [a + b] 

result = Counter(result)

plt.bar(
    x=result.keys(),
    height=result.values(),
    color="blue",
    width=3,
)

plt.ylabel("Count (number of same results)")
plt.xlabel("Sum of two Random Numbers (result)")

plt.axis([-100, max(result.keys()) + 100, 0, max(result.values()) + 10])

plt.show()
